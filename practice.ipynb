# %%
#Read a text file and count number of words
with open("text.html", "w")as f:
    text=f.write("hello, my name is simran, what are you doing   hi")

with open("text.html", "r")as f:
    text=f.read()
    words=text.split()
    count=len(words)
print(count)
# Out:
# 10
